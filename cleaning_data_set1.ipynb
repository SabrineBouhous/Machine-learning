# %% [markdown]
# # cleaning data set 1

# %%
# import library
import csv
import pandas as pd
from pandas import read_csv
# open text file
f = open('university.txt', 'r')
data = f.read()
f.close
l7=[]
file = open('university.txt', 'r').read()
file = file.split('\n')
for i in file:
    i.split('))')[0]
#create new text file data.text to make the text on it
fichier = open("data.txt", "a")
for univ in data.split(')'):
    for entry in univ.split('('):
            fichier.write(entry)
fichier.close()

# %%
# function to eliminate noisy data and replace them
def att_state():
    import re
    pattern = "def-instance "
    cont='control'
    state='state'
    file = open("data.txt", "r")
    l1=[]
    l2=[]
    sot='\n'
    u=0
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(state, line):
            if cont not in line :
                if state in line:
                        line=line.replace(state,'')
                        if sot in line:
                            line=line.replace(sot,'') 
                        if ' ' in line:
                            line=line.replace(" ", "")
                        l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:

                        if i+2 < len(l1):
                            if l1[i+2][0]==2:
                                o.append(l1[i+2][1])
                            else:
                                o.append(l1[i+1][1])





                    else:
                        o.append('')

        if o!=[]:
            j.append(o)

        i=i+1
    return (j)

# %%
# function to eliminate noisy data and replace them
 
def att_control():
    import re
    pattern = "def-instance "
    cont='control'
    file = open("data.txt", "r")
    l1=[]
    l2=[]
    sot='\n'
    u=0
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(cont, line):
            if cont in line:
                        line=line.replace(cont,'')
                        if sot in line:
                            line=line.replace(sot,'') 
                        if ' ' in line:
                            line=line.replace(" ", "")
                        if ':roman-catholic' in line:
                            line=line.replace(":roman-catholic", "")
                        if 'city' in line:
                            line=line.replace("city", "")
                        l1.append([2,line])    
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')



        if o!=[]:
            j.append(o)
        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_no_of_students():
    import re
    pattern = "def-instance "
    pattern1 = "no-of-students"
    file = open("data.txt", "r")
    t='thous'
    p=':'
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:

                line=line.replace(pattern1,'')
                line=line.replace(t,'')
                line=line.replace(p,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')



        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_male_femal_ratio():
    import re
    pattern = "def-instance "
    t='thous'
    p=':'
    sot='\n'
    pattern4= 'male:female'
    rat='ratio:'
    file = open("data.txt", "r")
    l1=[]
    l3=[]

    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern4, line):
            if pattern4 in line:
                line=line.replace(pattern4,'')
                if rat in line:
                    line=line.replace(rat,'')

                    if sot in line:
                        line=line.replace(sot,'')
                    if ' ' in line:
                        line=line.replace(" ", "")

                    l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')



        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_student_faculty():
    import re
    pattern = "def-instance "
    t='thous'
    p=':'
    sot='\n'
    pattern4= 'student:faculty'
    rat='ratio:'
    en='unavailable'
    en2='?'
    en3='%'
    en4='n/a'
    en5='ration:'
    file = open("data.txt", "r")
    l1=[]
    l3=[]

    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern4, line):
            if pattern4 in line:
                line=line.replace(pattern4,'')
                if rat in line:
                    line=line.replace(rat,'')

                if sot in line:
                    line=line.replace(sot,'')
                if en in line:
                    line=line.replace(en,'')
                if en2 in line:
                    line=line.replace(en2,'')
                if en3 in line:
                    line=line.replace(en3,'')
                if en4 in line:
                    line=line.replace(en4,'')
                if en5 in line:
                    line=line.replace(en5,'')
                if ' ' in line:
                    line=line.replace(" ", "")
       
                

                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')



        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_sate_verbal():
    import re
    pattern = "def-instance "
    t='thous'
    p=':'
    
    sot='\n'
    sat='sat'
    verbal='verbal'
    math='math'
    nop='no-applicants'
    ad='percent-admittance'
    qlt='quality-of-life' 
    scl='scale:'
    act=' act-'
    file = open("data.txt", "r")
    l1=[]

    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(verbal, line):
            if sat in line:
                line=line.replace(sat,'')
                if math not  in line:
                    if verbal in line:
                        line=line.replace(verbal,'')
                        if '%' in line:
                            line=line.replace('%','') 
                        if 'na' in line:
                            line=line.replace('na','')
                        if 'n/a' in line:
                            line=line.replace('n/a','')

                        if sot in line:
                            line=line.replace(sot,'')
                        if act in line:
                            line=line.replace(act,'')
                        if ' ' in line:
                            line=line.replace(" ", "")
                            

                        l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')

        if o!=[]:
            j.append(o)
        i=i+1
    return(j)

# %%
#function to eliminate noisy data and replace them
 
def att_sate_math():
    import re
    pattern = "def-instance "
    t='thous'
    p=':'
    sot='\n'
    sat='sat'
    act='act-'
    verbal='verbal'
    math='math'
    file = open("data.txt", "r")
    l1=[]

    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(math, line):
            if sat in line:
                line=line.replace(sat,'')
                if verbal not  in line:
                    if math in line:
                        line=line.replace(math,'')
                    if '%' in line:
                        line=line.replace('%','') 
                    if 'na' in line:
                        line=line.replace('na','')
                    if 'n/a' in line:
                        line=line.replace('n/a','')

                    if sot in line:
                        line=line.replace(sot,'')
                    if act in line:
                        line=line.replace(act,'')
                    if ' ' in line:
                        line=line.replace(" ", "")
                        

                    l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')

            
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_expenses():
    import re
    pattern = "def-instance "
    pattern1 = "expenses"
    file = open("data.txt", "r")
    t='thous$'
    p=':'
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:

                line=line.replace(pattern1,'')
                line=line.replace(t,'')
                line=line.replace(p,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')



        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_percent_financial_aid():
    import re
    pattern = "def-instance "
    pattern1 = "percent-financial-aid"
    file = open("data.txt", "r")
    sot='\n'
    en='%'
    en2='n/a'
   
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:
                line=line.replace(pattern1,'')
                if sot in line:
                    line=line.replace(sot,'')
                if en in line:
                    line=line.replace(en,'')
                if en2 in line:
                    line=line.replace(en2,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('0')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
## function to eliminate noisy data and replace them
  
def att_location ():
    import re
    pattern = "def-instance "
    pattern1 = "location "
    file = open("data.txt", "r")
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:
                line=line.replace(pattern1,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_percent_admittance ():
    import re
    pattern = "def-instance "
    pattern1 = "percent-admittance "
    file = open("data.txt", "r")
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:
                line=line.replace(pattern1,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_no_applicants():
    import re
    pattern = "def-instance "
    pattern1 = "no-applicants"
    file = open("data.txt", "r")
    t='thous'
    p=':'
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:

                line=line.replace(pattern1,'')
                line=line.replace(t,'')
                line=line.replace(p,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_no_percent_enrolled():
    import re
    pattern = "def-instance "
    pattern1 = "percent-enrolled"
    file = open("data.txt", "r")
    sot='\n'
    l1=[]
    for line in file: 
        if re.search(pattern, line):
            if pattern in line:
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line])
        if re.search(pattern1, line):
            if pattern1 in line:
                line=line.replace(pattern1,'')
                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")
                l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_quality_of_life():
    import re
    pattern = "def-instance "
    sot='\n'
    qlt='quality-of-life' 
    scl='scale:'
    file = open("data.txt", "r")
    l1=[]
    l3=[]

    u=0
    for line in file:
        u=u+1

        if re.search(pattern, line):

            if pattern in line:
                u=u+1
                l1.append([3,l3])
                l3=[]
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'')


                l1.append([1,line]) 
        if re.search(qlt, line):
            if qlt in line:
                line=line.replace(qlt,'')
                if scl in line:
                    line=line.replace(scl,'')

                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")

                    l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_academics():
    import re
    pattern = "def-instance "
    sot='\n'
    acad='academics' 
    scl='scale:'
    file = open("data.txt", "r")
    l1=[]
    l3=[]

    u=0
    for line in file:
        u=u+1

        if re.search(pattern, line):

            if pattern in line:
                u=u+1
                l1.append([3,l3])
                l3=[]
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'')


                l1.append([1,line]) 
        if re.search(acad, line):
            if acad in line:
                line=line.replace(acad,'')
                if scl in line:
                    line=line.replace(scl,'')

                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")

                    l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_social():
    import re
    pattern = "def-instance "
    sot='\n'
    acad='social' 
    scl='scale:'
    file = open("data.txt", "r")
    l1=[]
    l3=[]

    u=0
    for line in file:
        u=u+1

        if re.search(pattern, line):

            if pattern in line:
                u=u+1
                l1.append([3,l3])
                l3=[]
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'')


                l1.append([1,line]) 
        if re.search(acad, line):
            if acad in line:
                line=line.replace(acad,'')
                if scl in line:
                    line=line.replace(scl,'')

                if sot in line:
                    line=line.replace(sot,'')
                if ' ' in line:
                    line=line.replace(" ", "")

                    l1.append([2,line])
    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==2:
                        o.append(l1[i+1][1])           
                    else:
                        o.append('')
        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# function to eliminate noisy data and replace them
def att_academic_emphasis():
    import re
    pattern = "def-instance "

    sot='\n'
    pattern3 = "academic-emphasis"

    file = open("data.txt", "r")
    l1=[]
    l3=[]

    u=0
    for line in file:
        u=u+1

        if re.search(pattern, line):
            if pattern in line:
                l1.append([3,l3])
                l3=[]
                line=line.replace(pattern,'')
                if sot in line:
                    line=line.replace(sot,'') 
                l1.append([1,line]) 

        if re.search(pattern3, line):
            if pattern3 in line:
                line=line.replace(pattern3,'')
                if sot in line:
                    line=line.replace(sot,'')
                if '%' in line:
                    line=line.replace('%','')
                if '50' in line:
                    line=line.replace('50','')
                if 'hund:5-10' in line:
                    line=line.replace('hund:5-10','')
                
                    
                if ' ' in line:
                    line=line.replace(" ", "")
                l3.append(line)


        if u ==50264:
            l1.append([3,l3])

    i=0
    j=[]

    while i < len(l1):
        o=[]
        if l1[i][0]==1:

            o.append(l1[i][1])
            #print((l1[i][1]))
            if i+1 < len(l1):
                    if l1[i+1][0]==3:
                        if l1[i+1][1]==[]:
                            o.append('')
                            #print((l1[i+1][1]))
                        else:
                            o.append(l1[i+1][1])
                            #print((l1[i+1][1]))
                    else:
                        o.append('')

        if o!=[]:
            j.append(o)

        i=i+1
    return(j)

# %%
# called all the functions creates to  eliminate noisy data and replace them

a1=att_state()
a2=att_location ()
a3=att_control()
a4=att_no_of_students()
a5=att_male_femal_ratio()
a6=att_student_faculty()
a7=att_sate_verbal()
a8=att_sate_math()
a9=att_expenses()
a10=att_percent_financial_aid()
a11=att_no_applicants()
a12=att_percent_admittance()
a13=att_no_percent_enrolled()
a14=att_quality_of_life()
a15=att_academics()
a16=att_social()
a17=att_academic_emphasis()

# %%
# concatinate all the dat for each features 
f=[]
f1=[]
i=0
def combine1(a1):
    i=0
    f=[]
    while i < len(a1):
        f.append(a1[i][0])
        i=i+1

    return f
f0=combine1(a1)
def combine(a1):
    i=0
    f=[]
    while i < len(a15):
        f.append(a1[i][1])
        i=i+1
    return f        
f1=combine(a1) 
f2=combine(a2)
f3=combine(a3)
f4=combine(a4)
f5=combine(a5)
f6=combine(a6)
f7=combine(a7)
f8=combine(a8)
f9=combine(a9)
f10=combine(a10)
f11=combine(a11)
f12=combine(a12)
f13=combine(a13)
f14=combine(a14)
f15=combine(a15)
f16=combine(a16)

# %%
# make academics emphasis for each row  on f17

f17=[]
t=0
while t <len(a17):
    
    if t!=len(a17)-1:
        f17.append(a17[t][1])
    
    else:
        f17.append(['education' 'social-science' 'liberal-arts' 'business-administration' 'mathematics'])
    t=t+1

# %%
# make academics emphasis for each row on t
t=[]
for i in f17:
    if i!= '':
        for g in i:
            t.append(g)

# %%
# open new csv file
with open('univdata.csv', 'w', encoding='utf-8') as f:
    thewriter=csv.writer(f)

    thewriter.writerow(['University-name','State','location','Control','number-of-students','male:female (ratio)','student:faculty (ratio)','sat-verbal','sat-math','expenses','percent-financial-aid','number-of-applicants','percent-admittance','percent-enrolled','academics','social','quality-of-life',' academic-emphasis'])
    a = 0
    
           
    while a < 285 :
        if f17[a] != []:
            k=f17[a]
            l=''
            for h in k:
             
                l=l+ h+' '
        
        thewriter.writerow([f0[a],f1[a],f2[a],f3[a],f4[a],f5[a],f6[a],f7[a],f8[a],f9[a],f10[a],f11[a],f12[a],f13[a],f15[a],f16[a],f14[a],l])
            
        a=a+1
# read csv file
df=pd.read_csv("univdata.csv")
df.head()
# Out:
#      University-name          State  location  Control number-of-students  \
# 0            adelphi        newyork       NaN  private               5-10
# 1      arizona-state        arizona       NaN    state                20+
# 2     boston-college  massachusetts  suburban  private               5-10
# 3  boston-university  massachusetts     urban  private              10-15
# 4              brown    rhodeisland     urban  private                 5-
#
#   male:female (ratio) student:faculty (ratio)  sat-verbal  sat-math expenses  \
# 0               30:70                    15:1       500.0     475.0     7-10
# 1               50:50                    20:1       450.0     500.0      4-7
# 2               40:60                    20:1       500.0     550.0      10+
# 3               45:55                    12:1       550.0     575.0      10+
# 4               50:50                    11:1       625.0     650.0      10+
#
# ...

# %%
# display false for each features have a null data

df.isnull()
# Out:
#      University-name  State  location  Control  number-of-students  \
# 0              False  False      True    False               False
# 1              False  False      True    False               False
# 2              False  False     False    False               False
# 3              False  False     False    False               False
# 4              False  False     False    False               False
# ..               ...    ...       ...      ...                 ...
# 280            False  False     False    False               False
# 281            False  False     False    False               False
# 282            False  False     False    False               False
# 283            False  False     False    False               False
# 284            False  False     False    False               False
#
#      male:female (ratio)  student:faculty (ratio)  sat-verbal  sat-math  \
# 0                  False                    False       False     False
# ...

# %%
# display false for each features have a null data
df.isnull().any()
# Out:
# University-name            False
# State                      False
# location                    True
# Control                     True
# number-of-students         False
# male:female (ratio)        False
# student:faculty (ratio)     True
# sat-verbal                  True
# sat-math                    True
# expenses                   False
# percent-financial-aid       True
# number-of-applicants        True
# percent-admittance          True
# percent-enrolled            True
# academics                   True
# social                      True
# quality-of-life             True
#  academic-emphasis          True
# dtype: bool

# %%
# display the number of the null data for each features
df.isnull().sum()
# Out:
# University-name             0
# State                       0
# location                    6
# Control                     5
# number-of-students          0
# male:female (ratio)         0
# student:faculty (ratio)    22
# sat-verbal                 22
# sat-math                   22
# expenses                    0
# percent-financial-aid       1
# number-of-applicants        6
# percent-admittance          5
# percent-enrolled            4
# academics                   8
# social                      8
# quality-of-life            12
#  academic-emphasis         13
# dtype: int64

# %%
# the sum of the null values on the data set 
df.isnull().sum().sum()
# Out:
# 134
